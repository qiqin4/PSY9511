# %%
# Exercise 1
##Create a vector of 100 standard normally distributed numbers and visualize them with a histogram.
import numpy as np
from matplotlib.pyplot import subplots

nnumber=np.random.normal(size=100)
fig,ax=subplots(figsize=(8,8))
ax.hist(nnumber)
# Out:
# (array([ 2.,  8., 17., 10., 20., 21.,  8.,  5.,  2.,  7.]),
#  array([-1.92479416, -1.53472421, -1.14465426, -0.75458431, -0.36451437,
#          0.02555558,  0.41562553,  0.80569548,  1.19576543,  1.58583538,
#          1.97590533]),
#  <BarContainer object of 10 artists>)
