# %%
# Exercise 1
##Create a vector of 100 standard normally distributed numbers and visualize them with a histogram.
import numpy as np
from matplotlib.pyplot import subplots

nnumber=np.random.normal(size=100)
fig,ax=subplots(figsize=(6,4))
ax.hist(nnumber)
# Out:
# (array([ 1.,  2.,  5., 13., 18., 20., 22., 11.,  5.,  3.]),
#  array([-2.83263409, -2.31300468, -1.79337526, -1.27374584, -0.75411642,
#         -0.234487  ,  0.28514241,  0.80477183,  1.32440125,  1.84403067,
#          2.36366009]),
#  <BarContainer object of 10 artists>)

# %%
# Show rows 5, 8, 9, and 10 of the Auto dataset.
